# %% [markdown]
# <a href="https://colab.research.google.com/github/mandem296/AI-ML-Group-Task/blob/master/Feature_extraction_lesson.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
from numpy.linalg import svd 
from sklearn.decomposition import TruncatedSVD,PCA
from numpy import random

# %%
pca=PCA(2)
t_svd=TruncatedSVD(2)

# %%
size=100

# %%
generate=np.random.uniform(100,500,size)

# %% [markdown]
# Form random datasets

# %% [markdown]
# Place datasets in a pandas dataframe

# %% [markdown]
# Visualize data in a pandas

# %%
data={'Location':generate,'Size':generate,'Mall Near':generate,'Ambience':generate,'Rent':generate}

# %%
df=pd.DataFrame(data)

# %%
df
# Out:
#       Location        Size   Mall Near    Ambience        Rent
# 0   155.653469  155.653469  155.653469  155.653469  155.653469
# 1   238.238727  238.238727  238.238727  238.238727  238.238727
# 2   136.509952  136.509952  136.509952  136.509952  136.509952
# 3   380.936671  380.936671  380.936671  380.936671  380.936671
# 4   359.109365  359.109365  359.109365  359.109365  359.109365
# ..         ...         ...         ...         ...         ...
# 95  163.773517  163.773517  163.773517  163.773517  163.773517
# 96  130.827212  130.827212  130.827212  130.827212  130.827212
# 97  187.967811  187.967811  187.967811  187.967811  187.967811
# 98  430.189488  430.189488  430.189488  430.189488  430.189488
# 99  329.685950  329.685950  329.685950  329.685950  329.685950
#
# [100 rows x 5 columns]

# %% [markdown]
# Removing the target

# %%
df.drop("Rent", axis=1, inplace=True)

# %%
df
# Out:
#       Location        Size   Mall Near    Ambience
# 0   155.653469  155.653469  155.653469  155.653469
# 1   238.238727  238.238727  238.238727  238.238727
# 2   136.509952  136.509952  136.509952  136.509952
# 3   380.936671  380.936671  380.936671  380.936671
# 4   359.109365  359.109365  359.109365  359.109365
# ..         ...         ...         ...         ...
# 95  163.773517  163.773517  163.773517  163.773517
# 96  130.827212  130.827212  130.827212  130.827212
# 97  187.967811  187.967811  187.967811  187.967811
# 98  430.189488  430.189488  430.189488  430.189488
# 99  329.685950  329.685950  329.685950  329.685950
#
# [100 rows x 4 columns]

# %%
pca.fit_transform(df)
# Out:
# array([[ 2.99539360e+02,  2.71080281e-13],
#        [ 1.34368844e+02,  4.63356033e-16],
#        [ 3.37826393e+02, -8.09841334e-15],
#        [-1.51027045e+02,  1.56052169e-16],
#        [-1.07372432e+02, -8.15038283e-16],
#        [-2.32602870e+02,  8.14326215e-16],
#        [ 3.43286011e+02, -1.40262325e-14],
#        [ 8.30066266e+01, -8.76978308e-16],
#        [-1.00174085e+02, -9.13699448e-16],
#        [ 3.91175085e+02,  6.29992087e-15],
#        [-2.96648556e+02,  3.78714412e-16],
#        [ 2.01310998e+02, -6.92675318e-15],
#        [ 4.88372715e+01, -2.22818808e-15],
#        [-2.44554255e+02, -1.01409858e-15],
#        [ 4.63728990e+01, -1.67823459e-15],
#        [ 1.35238128e+02, -2.95768295e-15],
#        [-1.48263845e+02, -6.23301593e-16],
#        [ 2.99288440e+02, -1.02076089e-14],
#        [-2.65093083e+02,  6.41451452e-15],
#        [ 4.06822999e+01, -8.82313529e-16],
#        [-1.07054389e+02,  3.90713021e-15],
#        [-5.35844017e+01,  1.20502607e-15],
# ...

# %%
t_svd.fit_transform(df)
# Out:
# array([[ 3.11306937e+02, -2.67421435e-15],
#        [ 4.76477453e+02, -2.58523035e-14],
#        [ 2.73019905e+02, -1.52872876e-14],
#        [ 7.61873343e+02, -5.25453845e-14],
#        [ 7.18218729e+02, -4.45428604e-15],
#        [ 8.43449167e+02, -3.24151417e-14],
#        [ 2.67560286e+02, -1.36196396e-14],
#        [ 5.27839671e+02, -2.83082373e-14],
#        [ 7.11020382e+02, -3.10918561e-14],
#        [ 2.19671213e+02, -1.44260687e-14],
#        [ 9.07494854e+02, -6.28853283e-14],
#        [ 4.09535300e+02, -4.14861576e-14],
#        [ 5.62009026e+02, -3.21064738e-14],
#        [ 8.55400553e+02, -5.92712595e-14],
#        [ 5.64473399e+02, -2.62424694e-14],
#        [ 4.75608169e+02, -2.24713004e-14],
#        [ 7.59110143e+02, -7.90338747e-14],
#        [ 3.11557858e+02, -1.73330092e-14],
#        [ 8.75939380e+02, -5.36681679e-14],
#        [ 5.70163998e+02, -2.96153242e-14],
#        [ 7.17900686e+02, -3.34630731e-14],
#        [ 6.64430699e+02, -1.46017128e-15],
# ...
